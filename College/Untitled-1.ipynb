# %% [markdown]
# I will add background synchronization to `CalendarIntegrationManager.swift`.
# 1.  Add a `private var syncTimer: Timer?` to properties.
# 2.  Define `startBackgroundSync()` to scheduled a timer (e.g., every 15 minutes) that calls `performInitialSync()`.
# 3.  Define `stopBackgroundSync()` to invalidate the timer.
# 4.  Call `startBackgroundSync()` in `init` (if connected) and in `connectGoogle`'s success handler.
# 5.  Call `stopBackgroundSync()` in `disconnectGoogle`.
# 6.  Ensure `performInitialSync` is safe to call repeatedly (it is, as it updates existing events).

# %% [markdown]
# I will implement the "Update" logic for syncing changes from Google Calendar to the local app. Currently, the code has a placeholder `// Future: Update existing event logic here`. I will replace this with code to update the local event's title, dates, location, and notes based on the data fetched from Google.
